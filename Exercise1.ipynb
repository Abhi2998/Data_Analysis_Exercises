# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath='C:\\Users\\Dell\\Desktop\\Stats using Python\\archive(7)\\train.csv'
df=pd.read_csv(filepath)

# %%
# Descriptive Stats

#Calculating Mean Value for Sales column
sales_mean = df['Sales'].mean()

#Calculating Median Value for Sales column
sales_median = df['Sales'].median()

#Calculating Mode Value for Sales column
sales_mode = df['Sales'].mode()[0]  

#Calculating Variance for Sales column
sales_variance = df['Sales'].var()

#Calculating Standard Deviation for Sales column
sales_std = df['Sales'].std()


# Displaying the Descriptive Statistics for Sales 
print("Descriptive Statistics for Sales:")
print("\nMean: ",sales_mean)
print("\nMedian: ",sales_median)
print("\nMode: ",sales_mode)
print("\nStandard Deviation:",sales_std)
print("\nVariance:",sales_variance)
# Out:
# Descriptive Statistics for Sales:
#
# Mean:  230.7690594591837
#
# Median:  54.489999999999995
#
# Mode:  12.96
#
# Standard Deviation: 626.6518748388042
#
# Variance: 392692.5722389884

# %%
#Plotting Histogram for Sales 

plt.figure(figsize=(10, 6))
plt.hist(df['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.grid(axis='y')
plt.show()

# %%
#Plotting Box Plot

plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Sales'], color='orange')
plt.title("Boxplot of Sales")
plt.xlabel("Sales")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Convert 'Order Date' to datetime
# ----> 2 data['Order Date'] = pd.to_datetime(data['Order Date'])
#       4 # Line plot: Sales over time
#       5 sales_over_time = data.groupby(data['Order Date'].dt.to_period('M'))['Sales'].sum()
#
# NameError: name 'data' is not defined
